# %% [markdown]
# ## Pertanyaan :
# #### 1. Bagaimana Perbedaan Kondisi Lowongan Pekerjaan Pra-Covid19 dengan Pasca-Covid19?

# %% [markdown]
# ## Librarys

# %%
import numpy as np
import pandas as pd
import streamlit as str
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ### Jumlah Jenis Kelamin Tiap Tahun

# %% [markdown]
# ### Data Perkotaan

# %%
data_perkotaan_df = pd.read_csv("data\penduduk\data_rumah_tangga_perkotaan_kelamin.csv")
data_perkotaan_df.head()
# Out:
#          Provinsi  2009_laki-laki  2009_perempuan  2009_jumlah  \
# 0            Aceh           83.08           16.92        100.0
# 1  Sumatera Utara           84.35           15.65        100.0
# 2  Sumatera Barat           83.43           16.57        100.0
# 3         R i a u           90.23            9.77        100.0
# 4       J a m b i           88.65           11.35        100.0
#
#    2010_laki-laki  2010_perempuan  2010_jumlah  2011_laki-laki  \
# 0           83.77           16.23        100.0           82.44
# 1           85.59           14.41        100.0           85.73
# 2           82.93           17.07        100.0           83.45
# 3           88.84           11.16        100.0           89.57
# 4           87.52           12.48        100.0           87.88
#
#    2011_perempuan  2011_jumlah  ...  2021_jumlah  2022_laki-laki  \
# 0           17.56        100.0  ...        100.0           82.42
# 1           14.27        100.0  ...        100.0           84.38
# ...

# %% [markdown]
# ### Data Pedesaan

# %%
data_pedesaan_df = pd.read_csv("data\penduduk\data_rumah_tangga_pedesaan_kelamin.csv")
data_pedesaan_df.head()
# Out:
#          Provinsi  2009_laki-laki  2009_perempuan  2009_jumlah  \
# 0            Aceh           78.12           21.88        100.0
# 1  Sumatera Utara           84.96           15.04        100.0
# 2  Sumatera Barat           84.06           15.94        100.0
# 3         R i a u           90.18            9.82        100.0
# 4       J a m b i           89.76           10.24        100.0
#
#    2010_laki-laki  2010_perempuan  2010_jumlah  2011_laki-laki  \
# 0           79.11           20.89        100.0           80.25
# 1           84.72           15.28        100.0           84.36
# 2           83.40           16.60        100.0           83.56
# 3           90.81            9.19        100.0           90.95
# 4           89.40           10.60        100.0           89.02
#
#    2011_perempuan  2011_jumlah  ...  2021_jumlah  2022_laki-laki  \
# 0           19.75        100.0  ...        100.0           80.67
# 1           15.64        100.0  ...        100.0           85.75
# ...

# %% [markdown]
# #

# %% [markdown]
# ### Data Pencari, Terdaftar, dan Pemenuhan Tenaga Kerja

# %% [markdown]
# ### 2021

# %%
data_pekerjaan2021_df = pd.read_csv("data\lowongan\data_pencari_lowongan_pemenuhan_tenaga_kerja_terdaftar_2021.csv")
data_pekerjaan2021_df.head()
# Out:
#          Provinsi  Pencari Kerja Terdaftar - Laki-Laki  \
# 0            Aceh                                 8742
# 1  Sumatera Utara                                28257
# 2  Sumatera Barat                                18751
# 3            Riau                                16517
# 4           Jambi                                14881
#
#    Pencari Kerja Terdaftar - Perempuan  Pencari Kerja Terdaftar - Jumlah  \
# 0                                 5235                             13977
# 1                                24285                             52542
# 2                                17534                             36285
# 3                                 8535                             25052
# 4                                 8343                             23224
#
#    Lowongan Kerja Terdaftar - Laki-Laki  Lowongan Kerja Terdaftar - Perempuan  \
# 0                                   577                                   570
# ...

# %% [markdown]
# ### 2020

# %%
data_pekerjaan2020_df = pd.read_csv("data\lowongan\data_pencari_lowongan_pemenuhan_tenaga_kerja_terdaftar_2020.csv")
data_pekerjaan2020_df.head()
# Out:
#          Provinsi  Pencari Kerja Terdaftar - Laki-Laki  \
# 0            Aceh                                83464
# 1  Sumatera Utara                               224983
# 2  Sumatera Barat                                92978
# 3            Riau                               269302
# 4           Jambi                                59306
#
#    Pencari Kerja Terdaftar - Perempuan  Pencari Kerja Terdaftar - Jumlah  \
# 0                                63586                            147050
# 1                               177591                            402574
# 2                                74111                            167089
# 3                               100599                            369901
# 4                                46998                            106304
#
#    Lowongan Kerja Terdaftar - Laki-Laki  Lowongan Kerja Terdaftar - Perempuan  \
# 0                                 63277                                 39358
# ...

# %% [markdown]
# ### 2019

# %%
data_pekerjaan2019_df = pd.read_csv("data\lowongan\data_pencari_lowongan_pemenuhan_tenaga_kerja_terdaftar_2019.csv")
data_pekerjaan2019_df.head()
# Out:
#          Provinsi  Pencari Kerja Terdaftar - Laki-Laki  \
# 0            Aceh                                  771
# 1  Sumatera Utara                                 5585
# 2  Sumatera Barat                                 4551
# 3            Riau                                 3963
# 4           Jambi                                 4079
#
#    Pencari Kerja Terdaftar - Perempuan  Pencari Kerja Terdaftar - Jumlah  \
# 0                                 1002                              1773
# 1                                 7721                             13306
# 2                                 5828                             10379
# 3                                 2607                              6570
# 4                                 3102                              7181
#
#    Lowongan Kerja Terdaftar - Laki-Laki  Lowongan Kerja Terdaftar - Perempuan  \
# 0                                   153                                   260
# ...

# %% [markdown]
# ### 2018

# %%
data_pekerjaan2018_df = pd.read_csv("data\lowongan\data_pencari_lowongan_pemenuhan_tenaga_kerja_terdaftar_2018.csv")
data_pekerjaan2018_df.head()
# Out:
#          Provinsi  Pencari Kerja Terdaftar - Laki-Laki  \
# 0            Aceh                                  855
# 1  Sumatera Utara                                 2324
# 2  Sumatera Barat                                 4522
# 3            Riau                                 1879
# 4           Jambi                                 1865
#
#    Pencari Kerja Terdaftar - Perempuan  Pencari Kerja Terdaftar - Jumlah  \
# 0                                  480                              1335
# 1                                 3644                              5968
# 2                                 6753                             11275
# 3                                 1740                              3619
# 4                                 1458                              3323
#
#    Lowongan Kerja Terdaftar - Laki-Laki  Lowongan Kerja Terdaftar - Perempuan  \
# 0                                    36                                    36
# ...

# %% [markdown]
# #

# %% [markdown]
# ### Data Jumlah Penduduk Provinsi dan Status Pekerjaannya

# %% [markdown]
# ### 2018

# %%
status_pekerjaan2018_df = pd.read_csv("data\penduduk\data_jumlah_penduduk_provinsi_dan_jenis_kegiatan_2018.csv")
status_pekerjaan2018_df.head()
# Out:
#          Provinsi  Angkatan Kerja - Bekerja  \
# 0            Aceh                   2203717
# 1  Sumatera Utara                   6728431
# 2  Sumatera Barat                   2410450
# 3            Riau                   2915597
# 4           Jambi                   1721362
#
#    Angkatan Kerja Pengangguran - Pernah Bekerja  \
# 0                                         36176
# 1                                        153847
# 2                                         49311
# 3                                         76978
# 4                                         25225
#
#    Angkatan Kerja Pengangguran - Tidak Pernah Bekerja  \
# 0                                             113547
# 1                                             242180
# 2                                              92369
# 3                                             115823
# 4                                              43850
#
#    Angkatan Kerja Pengangguran - Jumlah  \
# ...

# %% [markdown]
# ### 2019

# %%
status_pekerjaan2019_df = pd.read_csv("data\penduduk\data_jumlah_penduduk_provinsi_dan_jenis_kegiatan_2019.csv")
status_pekerjaan2019_df.head()
# Out:
#          Provinsi  Angkatan Kerja - Bekerja  \
# 0            Aceh                   2219698
# 1  Sumatera Utara                   6681224
# 2  Sumatera Barat                   2460554
# 3            Riau                   2996079
# 4           Jambi                   1691782
#
#    Angkatan Kerja Pengangguran - Pernah Bekerja  \
# 0                                         38459
# 1                                        191274
# 2                                         60938
# 3                                         84774
# 4                                         27903
#
#    Angkatan Kerja Pengangguran - Tidak Pernah Bekerja  \
# 0                                             108163
# 1                                             191164
# 2                                              77521
# 3                                             105369
# 4                                              46062
#
#    Angkatan Kerja Pengangguran - Jumlah  \
# ...

# %% [markdown]
# ### 2020

# %%
status_pekerjaan2020_df = pd.read_csv("data\penduduk\data_jumlah_penduduk_provinsi_dan_jenis_kegiatan_2020.csv")
status_pekerjaan2020_df.head()
# Out:
#          Provinsi  Angkatan Kerja - Bekerja  \
# 0            Aceh                   2359905
# 1  Sumatera Utara                   6842252
# 2  Sumatera Barat                   2581524
# 3            Riau                   3022988
# 4           Jambi                   1739003
#
#    Angkatan Kerja Pengangguran - Pernah Bekerja  \
# 0                                         63690
# 1                                        281623
# 2                                        106714
# 3                                        113177
# 4                                         43312
#
#    Angkatan Kerja Pengangguran - Tidak Pernah Bekerja  \
# 0                                             102910
# 1                                             226182
# 2                                              83895
# 3                                              90660
# 4                                              50678
#
#    Angkatan Kerja Pengangguran - Jumlah  \
# ...

# %% [markdown]
# ### 2021

# %%
status_pekerjaan2021_df = pd.read_csv("data\penduduk\data_jumlah_penduduk_provinsi_dan_jenis_kegiatan_2021.csv")
status_pekerjaan2021_df.head()
# Out:
#          Provinsi  Angkatan Kerja - Bekerja  \
# 0            Aceh                   2361300
# 1  Sumatera Utara                   7035850
# 2  Sumatera Barat                   2581444
# 3            Riau                   3148947
# 4           Jambi                   1746840
#
#    Angkatan Kerja Pengangguran - Pernah Bekerja  \
# 0                                         42389
# 1                                        222142
# 2                                         93464
# 3                                         78151
# 4                                         36856
#
#    Angkatan Kerja Pengangguran - Tidak Pernah Bekerja  \
# 0                                             116468
# 1                                             253014
# 2                                              86484
# 3                                              67518
# 4                                              56898
#
#    Angkatan Kerja Pengangguran - Jumlah  \
# ...

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# ### Mengubah Tipe Data

# %% [markdown]
# ### Jumlah Jenis Kelamin Perkotaan

# %%
data_perkotaan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 49 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provinsi        39 non-null     object
#  1   2009_laki-laki  39 non-null     float64
#  2   2009_perempuan  39 non-null     float64
#  3   2009_jumlah     39 non-null     float64
#  4   2010_laki-laki  39 non-null     float64
#  5   2010_perempuan  39 non-null     float64
#  6   2010_jumlah     39 non-null     float64
#  7   2011_laki-laki  39 non-null     float64
#  8   2011_perempuan  39 non-null     float64
#  9   2011_jumlah     39 non-null     float64
#  10  2012_laki-laki  39 non-null     float64
#  11  2012_perempuan  39 non-null     float64
#  12  2012_jumlah     39 non-null     float64
#  13  2013_laki-laki  39 non-null     float64
#  14  2013_perempuan  39 non-null     float64
#  15  2013_jumlah     39 non-null     float64
#  16  2014_laki-laki  39 non-null     float64
# ...

# %%
data_perkotaan_df['2009_laki-laki']= pd.to_numeric(data_perkotaan_df['2009_laki-laki'], errors='coerce')
data_perkotaan_df['2010_laki-laki']= pd.to_numeric(data_perkotaan_df['2010_laki-laki'], errors='coerce')
data_perkotaan_df['2011_laki-laki']= pd.to_numeric(data_perkotaan_df['2011_laki-laki'], errors='coerce')
data_perkotaan_df['2012_laki-laki']= pd.to_numeric(data_perkotaan_df['2012_laki-laki'], errors='coerce')
data_perkotaan_df['2013_laki-laki']= pd.to_numeric(data_perkotaan_df['2013_laki-laki'], errors='coerce')
data_perkotaan_df['2014_laki-laki']= pd.to_numeric(data_perkotaan_df['2014_laki-laki'], errors='coerce')
data_perkotaan_df['2015_laki-laki']= pd.to_numeric(data_perkotaan_df['2015_laki-laki'], errors='coerce')
data_perkotaan_df['2016_laki-laki']= pd.to_numeric(data_perkotaan_df['2016_laki-laki'], errors='coerce')
data_perkotaan_df['2017_laki-laki']= pd.to_numeric(data_perkotaan_df['2017_laki-laki'], errors='coerce')
data_perkotaan_df['2018_laki-laki']= pd.to_numeric(data_perkotaan_df['2018_laki-laki'], errors='coerce')
data_perkotaan_df['2019_laki-laki']= pd.to_numeric(data_perkotaan_df['2019_laki-laki'], errors='coerce')
data_perkotaan_df['2020_laki-laki']= pd.to_numeric(data_perkotaan_df['2020_laki-laki'], errors='coerce')
data_perkotaan_df['2021_laki-laki']= pd.to_numeric(data_perkotaan_df['2021_laki-laki'], errors='coerce')
data_perkotaan_df['2022_laki-laki']= pd.to_numeric(data_perkotaan_df['2022_laki-laki'], errors='coerce')
data_perkotaan_df['2023_laki-laki']= pd.to_numeric(data_perkotaan_df['2023_laki-laki'], errors='coerce')

data_perkotaan_df['2009_jumlah'] = pd.to_numeric(data_perkotaan_df['2009_jumlah'], errors='coerce')
data_perkotaan_df['2010_jumlah'] = pd.to_numeric(data_perkotaan_df['2010_jumlah'], errors='coerce')
data_perkotaan_df['2011_jumlah'] = pd.to_numeric(data_perkotaan_df['2011_jumlah'], errors='coerce')
data_perkotaan_df['2012_jumlah'] = pd.to_numeric(data_perkotaan_df['2012_jumlah'], errors='coerce')
data_perkotaan_df['2013_jumlah'] = pd.to_numeric(data_perkotaan_df['2013_jumlah'], errors='coerce')
data_perkotaan_df['2014_jumlah'] = pd.to_numeric(data_perkotaan_df['2014_jumlah'], errors='coerce')
data_perkotaan_df['2015_jumlah'] = pd.to_numeric(data_perkotaan_df['2015_jumlah'], errors='coerce')
data_perkotaan_df['2016_jumlah'] = pd.to_numeric(data_perkotaan_df['2016_jumlah'], errors='coerce')
data_perkotaan_df['2017_jumlah'] = pd.to_numeric(data_perkotaan_df['2017_jumlah'], errors='coerce')
data_perkotaan_df['2018_jumlah'] = pd.to_numeric(data_perkotaan_df['2018_jumlah'], errors='coerce')
data_perkotaan_df['2019_jumlah'] = pd.to_numeric(data_perkotaan_df['2019_jumlah'], errors='coerce')
data_perkotaan_df['2020_jumlah'] = pd.to_numeric(data_perkotaan_df['2020_jumlah'], errors='coerce')
data_perkotaan_df['2021_jumlah'] = pd.to_numeric(data_perkotaan_df['2021_jumlah'], errors='coerce')
data_perkotaan_df['2022_jumlah'] = pd.to_numeric(data_perkotaan_df['2022_jumlah'], errors='coerce')
data_perkotaan_df['2023_jumlah'] = pd.to_numeric(data_perkotaan_df['2023_jumlah'], errors='coerce')

data_perkotaan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 49 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provinsi        39 non-null     object
#  1   2009_laki-laki  39 non-null     float64
#  2   2009_perempuan  39 non-null     float64
#  3   2009_jumlah     39 non-null     float64
#  4   2010_laki-laki  39 non-null     float64
#  5   2010_perempuan  39 non-null     float64
#  6   2010_jumlah     39 non-null     float64
#  7   2011_laki-laki  39 non-null     float64
#  8   2011_perempuan  39 non-null     float64
#  9   2011_jumlah     39 non-null     float64
#  10  2012_laki-laki  39 non-null     float64
#  11  2012_perempuan  39 non-null     float64
#  12  2012_jumlah     39 non-null     float64
#  13  2013_laki-laki  39 non-null     float64
#  14  2013_perempuan  39 non-null     float64
#  15  2013_jumlah     39 non-null     float64
#  16  2014_laki-laki  39 non-null     float64
# ...

# %% [markdown]
# ### Jumlah Jenis Kelamin Perdesaan

# %%
data_pedesaan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 49 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provinsi        39 non-null     object
#  1   2009_laki-laki  39 non-null     float64
#  2   2009_perempuan  39 non-null     float64
#  3   2009_jumlah     39 non-null     float64
#  4   2010_laki-laki  39 non-null     float64
#  5   2010_perempuan  39 non-null     float64
#  6   2010_jumlah     39 non-null     float64
#  7   2011_laki-laki  39 non-null     float64
#  8   2011_perempuan  39 non-null     float64
#  9   2011_jumlah     39 non-null     float64
#  10  2012_laki-laki  39 non-null     float64
#  11  2012_perempuan  39 non-null     float64
#  12  2012_jumlah     39 non-null     float64
#  13  2013_laki-laki  39 non-null     float64
#  14  2013_perempuan  39 non-null     float64
#  15  2013_jumlah     39 non-null     float64
#  16  2014_laki-laki  39 non-null     float64
# ...

# %%
data_pedesaan_df['2009_laki-laki']= pd.to_numeric(data_pedesaan_df['2009_laki-laki'], errors='coerce')
data_pedesaan_df['2010_laki-laki']= pd.to_numeric(data_pedesaan_df['2010_laki-laki'], errors='coerce')
data_pedesaan_df['2011_laki-laki']= pd.to_numeric(data_pedesaan_df['2011_laki-laki'], errors='coerce')
data_pedesaan_df['2012_laki-laki']= pd.to_numeric(data_pedesaan_df['2012_laki-laki'], errors='coerce')
data_pedesaan_df['2013_laki-laki']= pd.to_numeric(data_pedesaan_df['2013_laki-laki'], errors='coerce')
data_pedesaan_df['2014_laki-laki']= pd.to_numeric(data_pedesaan_df['2014_laki-laki'], errors='coerce')
data_pedesaan_df['2015_laki-laki']= pd.to_numeric(data_pedesaan_df['2015_laki-laki'], errors='coerce')
data_pedesaan_df['2016_laki-laki']= pd.to_numeric(data_pedesaan_df['2016_laki-laki'], errors='coerce')
data_pedesaan_df['2017_laki-laki']= pd.to_numeric(data_pedesaan_df['2017_laki-laki'], errors='coerce')
data_pedesaan_df['2018_laki-laki']= pd.to_numeric(data_pedesaan_df['2018_laki-laki'], errors='coerce')
data_pedesaan_df['2019_laki-laki']= pd.to_numeric(data_pedesaan_df['2019_laki-laki'], errors='coerce')
data_pedesaan_df['2020_laki-laki']= pd.to_numeric(data_pedesaan_df['2020_laki-laki'], errors='coerce')
data_pedesaan_df['2021_laki-laki']= pd.to_numeric(data_pedesaan_df['2021_laki-laki'], errors='coerce')
data_pedesaan_df['2022_laki-laki']= pd.to_numeric(data_pedesaan_df['2022_laki-laki'], errors='coerce')
data_pedesaan_df['2023_laki-laki']= pd.to_numeric(data_pedesaan_df['2023_laki-laki'], errors='coerce')

data_pedesaan_df['2009_jumlah'] = pd.to_numeric(data_pedesaan_df['2009_jumlah'], errors='coerce')
data_pedesaan_df['2010_jumlah'] = pd.to_numeric(data_pedesaan_df['2010_jumlah'], errors='coerce')
data_pedesaan_df['2011_jumlah'] = pd.to_numeric(data_pedesaan_df['2011_jumlah'], errors='coerce')
data_pedesaan_df['2012_jumlah'] = pd.to_numeric(data_pedesaan_df['2012_jumlah'], errors='coerce')
data_pedesaan_df['2013_jumlah'] = pd.to_numeric(data_pedesaan_df['2013_jumlah'], errors='coerce')
data_pedesaan_df['2014_jumlah'] = pd.to_numeric(data_pedesaan_df['2014_jumlah'], errors='coerce')
data_pedesaan_df['2015_jumlah'] = pd.to_numeric(data_pedesaan_df['2015_jumlah'], errors='coerce')
data_pedesaan_df['2016_jumlah'] = pd.to_numeric(data_pedesaan_df['2016_jumlah'], errors='coerce')
data_pedesaan_df['2017_jumlah'] = pd.to_numeric(data_pedesaan_df['2017_jumlah'], errors='coerce')
data_pedesaan_df['2018_jumlah'] = pd.to_numeric(data_pedesaan_df['2018_jumlah'], errors='coerce')
data_pedesaan_df['2019_jumlah'] = pd.to_numeric(data_pedesaan_df['2019_jumlah'], errors='coerce')
data_pedesaan_df['2020_jumlah'] = pd.to_numeric(data_pedesaan_df['2020_jumlah'], errors='coerce')
data_pedesaan_df['2021_jumlah'] = pd.to_numeric(data_pedesaan_df['2021_jumlah'], errors='coerce')
data_pedesaan_df['2022_jumlah'] = pd.to_numeric(data_pedesaan_df['2022_jumlah'], errors='coerce')
data_pedesaan_df['2023_jumlah'] = pd.to_numeric(data_pedesaan_df['2023_jumlah'], errors='coerce')

data_perkotaan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 49 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provinsi        39 non-null     object
#  1   2009_laki-laki  39 non-null     float64
#  2   2009_perempuan  39 non-null     float64
#  3   2009_jumlah     39 non-null     float64
#  4   2010_laki-laki  39 non-null     float64
#  5   2010_perempuan  39 non-null     float64
#  6   2010_jumlah     39 non-null     float64
#  7   2011_laki-laki  39 non-null     float64
#  8   2011_perempuan  39 non-null     float64
#  9   2011_jumlah     39 non-null     float64
#  10  2012_laki-laki  39 non-null     float64
#  11  2012_perempuan  39 non-null     float64
#  12  2012_jumlah     39 non-null     float64
#  13  2013_laki-laki  39 non-null     float64
#  14  2013_perempuan  39 non-null     float64
#  15  2013_jumlah     39 non-null     float64
#  16  2014_laki-laki  39 non-null     float64
# ...

# %% [markdown]
# ### Data Pencari, Terdaftar, dan Pemenuhan Tenaga Kerja

# %%
data_pekerjaan2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Provinsi                                       35 non-null     object
#  1   Pencari Kerja Terdaftar - Laki-Laki            35 non-null     int64
#  2   Pencari Kerja Terdaftar - Perempuan            35 non-null     int64
#  3   Pencari Kerja Terdaftar - Jumlah               35 non-null     int64
#  4   Lowongan Kerja Terdaftar - Laki-Laki           35 non-null     int64
#  5   Lowongan Kerja Terdaftar - Perempuan           35 non-null     int64
#  6   Lowongan Kerja Terdaftar - Jumlah              35 non-null     int64
#  7   Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki  35 non-null     int64
#  8   Penempatan/Pemenuhan Tenaga Kerja - Perempuan  35 non-null     int64
# ...

# %%
data_pekerjaan2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Provinsi                                       35 non-null     object
#  1   Pencari Kerja Terdaftar - Laki-Laki            35 non-null     int64
#  2   Pencari Kerja Terdaftar - Perempuan            35 non-null     int64
#  3   Pencari Kerja Terdaftar - Jumlah               35 non-null     int64
#  4   Lowongan Kerja Terdaftar - Laki-Laki           35 non-null     int64
#  5   Lowongan Kerja Terdaftar - Perempuan           35 non-null     int64
#  6   Lowongan Kerja Terdaftar - Jumlah              35 non-null     int64
#  7   Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki  35 non-null     int64
#  8   Penempatan/Pemenuhan Tenaga Kerja - Perempuan  35 non-null     int64
# ...

# %%
data_pekerjaan2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Provinsi                                       35 non-null     object
#  1   Pencari Kerja Terdaftar - Laki-Laki            35 non-null     int64
#  2   Pencari Kerja Terdaftar - Perempuan            35 non-null     int64
#  3   Pencari Kerja Terdaftar - Jumlah               35 non-null     int64
#  4   Lowongan Kerja Terdaftar - Laki-Laki           35 non-null     int64
#  5   Lowongan Kerja Terdaftar - Perempuan           35 non-null     int64
#  6   Lowongan Kerja Terdaftar - Jumlah              35 non-null     int64
#  7   Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki  35 non-null     int64
#  8   Penempatan/Pemenuhan Tenaga Kerja - Perempuan  34 non-null     float64
# ...

# %%
data_pekerjaan2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Provinsi                                       35 non-null     object
#  1   Pencari Kerja Terdaftar - Laki-Laki            35 non-null     int64
#  2   Pencari Kerja Terdaftar - Perempuan            35 non-null     int64
#  3   Pencari Kerja Terdaftar - Jumlah               35 non-null     int64
#  4   Lowongan Kerja Terdaftar - Laki-Laki           35 non-null     int64
#  5   Lowongan Kerja Terdaftar - Perempuan           35 non-null     int64
#  6   Lowongan Kerja Terdaftar - Jumlah              35 non-null     int64
#  7   Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki  35 non-null     int64
#  8   Penempatan/Pemenuhan Tenaga Kerja - Perempuan  35 non-null     int64
# ...

# %% [markdown]
# ### Data Jumlah Penduduk Provinsi dan Status Pekerjaannya

# %%
status_pekerjaan2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 13 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Provinsi                                                     35 non-null     object
#  1   Angkatan Kerja - Bekerja                                     35 non-null     int64
#  2   Angkatan Kerja Pengangguran - Pernah Bekerja                 35 non-null     int64
#  3   Angkatan Kerja Pengangguran - Tidak Pernah Bekerja           35 non-null     int64
#  4   Angkatan Kerja Pengangguran - Jumlah                         35 non-null     int64
#  5   Angkatan Kerja - Jumlah Angkatan Kerja                       35 non-null     int64
#  6   Angkatan Kerja - Persentase Bekerja terhadap Angkatan Kerja  35 non-null     float64
# ...

# %%
status_pekerjaan2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 13 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Provinsi                                                     35 non-null     object
#  1   Angkatan Kerja - Bekerja                                     35 non-null     int64
#  2   Angkatan Kerja Pengangguran - Pernah Bekerja                 35 non-null     int64
#  3   Angkatan Kerja Pengangguran - Tidak Pernah Bekerja           35 non-null     int64
#  4   Angkatan Kerja Pengangguran - Jumlah                         35 non-null     int64
#  5   Angkatan Kerja - Jumlah Angkatan Kerja                       35 non-null     int64
#  6   Angkatan Kerja - Persentase Bekerja terhadap Angkatan Kerja  35 non-null     float64
# ...

# %%
status_pekerjaan2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 13 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Provinsi                                                     35 non-null     object
#  1   Angkatan Kerja - Bekerja                                     35 non-null     int64
#  2   Angkatan Kerja Pengangguran - Pernah Bekerja                 35 non-null     int64
#  3   Angkatan Kerja Pengangguran - Tidak Pernah Bekerja           35 non-null     int64
#  4   Angkatan Kerja Pengangguran - Jumlah                         35 non-null     int64
#  5   Angkatan Kerja - Jumlah Angkatan Kerja                       35 non-null     int64
#  6   Angkatan Kerja - Persentase Bekerja terhadap Angkatan Kerja  35 non-null     float64
# ...

# %% [markdown]
# ### 2021

# %%
status_pekerjaan2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 13 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Provinsi                                                     35 non-null     object
#  1   Angkatan Kerja - Bekerja                                     35 non-null     int64
#  2   Angkatan Kerja Pengangguran - Pernah Bekerja                 35 non-null     int64
#  3   Angkatan Kerja Pengangguran - Tidak Pernah Bekerja           35 non-null     int64
#  4   Angkatan Kerja Pengangguran - Jumlah                         35 non-null     int64
#  5   Angkatan Kerja - Jumlah Angkatan Kerja                       35 non-null     int64
#  6   Angkatan Kerja - Persentase Bekerja terhadap Angkatan Kerja  35 non-null     float64
# ...

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ### Mengechek Missing Value

# %% [markdown]
# ### Jumlah Jenis Kelamin Tiap Tahun

# %% [markdown]
# ### Data Perkotaan

# %%
data_perkotaan_df.isnull().sum()
# Out:
# Provinsi          0
# 2009_laki-laki    0
# 2009_perempuan    0
# 2009_jumlah       0
# 2010_laki-laki    0
# 2010_perempuan    0
# 2010_jumlah       0
# 2011_laki-laki    0
# 2011_perempuan    0
# 2011_jumlah       0
# 2012_laki-laki    0
# 2012_perempuan    0
# 2012_jumlah       0
# 2013_laki-laki    0
# 2013_perempuan    0
# 2013_jumlah       0
# 2014_laki-laki    0
# 2014_perempuan    0
# 2014_jumlah       0
# 2015_laki-laki    0
# 2015_perempuan    0
# 2015_jumlah       0
# 2016_laki-laki    0
# 2016_perempuan    0
# 2016_jumlah       0
# 2017_laki-laki    0
# 2017_perempuan    0
# 2017_jumlah       0
# 2018_laki-laki    0
# 2018_perempuan    0
# 2018_jumlah       0
# 2019_laki-laki    0
# 2019_perempuan    0
# 2019_jumlah       0
# 2020_laki-laki    0
# 2020_perempuan    0
# 2020_jumlah       0
# 2021_laki-laki    0
# 2021_perempuan    0
# 2021_jumlah       0
# 2022_laki-laki    0
# 2022_perempuan    0
# 2022_jumlah       0
# 2023_laki-laki    0
# 2023_perempuan    0
# ...

# %% [markdown]
# ### Data Pedesaan

# %%
data_perkotaan_df.isnull().sum()
# Out:
# Provinsi          0
# 2009_laki-laki    0
# 2009_perempuan    0
# 2009_jumlah       0
# 2010_laki-laki    0
# 2010_perempuan    0
# 2010_jumlah       0
# 2011_laki-laki    0
# 2011_perempuan    0
# 2011_jumlah       0
# 2012_laki-laki    0
# 2012_perempuan    0
# 2012_jumlah       0
# 2013_laki-laki    0
# 2013_perempuan    0
# 2013_jumlah       0
# 2014_laki-laki    0
# 2014_perempuan    0
# 2014_jumlah       0
# 2015_laki-laki    0
# 2015_perempuan    0
# 2015_jumlah       0
# 2016_laki-laki    0
# 2016_perempuan    0
# 2016_jumlah       0
# 2017_laki-laki    0
# 2017_perempuan    0
# 2017_jumlah       0
# 2018_laki-laki    0
# 2018_perempuan    0
# 2018_jumlah       0
# 2019_laki-laki    0
# 2019_perempuan    0
# 2019_jumlah       0
# 2020_laki-laki    0
# 2020_perempuan    0
# 2020_jumlah       0
# 2021_laki-laki    0
# 2021_perempuan    0
# 2021_jumlah       0
# 2022_laki-laki    0
# 2022_perempuan    0
# 2022_jumlah       0
# 2023_laki-laki    0
# 2023_perempuan    0
# ...

# %% [markdown]
# ### Data Pencari, Terdaftar, dan Pemenuhan Tenaga Kerja

# %% [markdown]
# ### 2021

# %%
data_pekerjaan2021_df.isnull().sum()
# Out:
# Provinsi                                         0
# Pencari Kerja Terdaftar - Laki-Laki              0
# Pencari Kerja Terdaftar - Perempuan              0
# Pencari Kerja Terdaftar - Jumlah                 0
# Lowongan Kerja Terdaftar - Laki-Laki             0
# Lowongan Kerja Terdaftar - Perempuan             0
# Lowongan Kerja Terdaftar - Jumlah                0
# Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki    0
# Penempatan/Pemenuhan Tenaga Kerja - Perempuan    0
# Penempatan/Pemenuhan Tenaga Kerja - Jumlah       0
# dtype: int64

# %% [markdown]
# ### 2020

# %%
data_pekerjaan2020_df.isnull().sum()
# Out:
# Provinsi                                         0
# Pencari Kerja Terdaftar - Laki-Laki              0
# Pencari Kerja Terdaftar - Perempuan              0
# Pencari Kerja Terdaftar - Jumlah                 0
# Lowongan Kerja Terdaftar - Laki-Laki             0
# Lowongan Kerja Terdaftar - Perempuan             0
# Lowongan Kerja Terdaftar - Jumlah                0
# Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki    0
# Penempatan/Pemenuhan Tenaga Kerja - Perempuan    0
# Penempatan/Pemenuhan Tenaga Kerja - Jumlah       0
# dtype: int64

# %% [markdown]
# ### 2019

# %%
data_pekerjaan2019_df.isnull().sum()
# Out:
# Provinsi                                         0
# Pencari Kerja Terdaftar - Laki-Laki              0
# Pencari Kerja Terdaftar - Perempuan              0
# Pencari Kerja Terdaftar - Jumlah                 0
# Lowongan Kerja Terdaftar - Laki-Laki             0
# Lowongan Kerja Terdaftar - Perempuan             0
# Lowongan Kerja Terdaftar - Jumlah                0
# Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki    0
# Penempatan/Pemenuhan Tenaga Kerja - Perempuan    1
# Penempatan/Pemenuhan Tenaga Kerja - Jumlah       0
# dtype: int64

# %% [markdown]
# ### 2018

# %%
data_pekerjaan2018_df.isnull().sum()
# Out:
# Provinsi                                         0
# Pencari Kerja Terdaftar - Laki-Laki              0
# Pencari Kerja Terdaftar - Perempuan              0
# Pencari Kerja Terdaftar - Jumlah                 0
# Lowongan Kerja Terdaftar - Laki-Laki             0
# Lowongan Kerja Terdaftar - Perempuan             0
# Lowongan Kerja Terdaftar - Jumlah                0
# Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki    0
# Penempatan/Pemenuhan Tenaga Kerja - Perempuan    0
# Penempatan/Pemenuhan Tenaga Kerja - Jumlah       0
# dtype: int64

# %% [markdown]
# ### Jenis Pekerjaan Berdasarkan Jenis Kelamin dan Usia Tiap Tahun

# %% [markdown]
# ### 2021

# %%
status_pekerjaan2021_df.isna().sum()
# Out:
# Provinsi                                                       0
# Angkatan Kerja - Bekerja                                       0
# Angkatan Kerja Pengangguran - Pernah Bekerja                   0
# Angkatan Kerja Pengangguran - Tidak Pernah Bekerja             0
# Angkatan Kerja Pengangguran - Jumlah                           0
# Angkatan Kerja - Jumlah Angkatan Kerja                         0
# Angkatan Kerja - Persentase Bekerja terhadap Angkatan Kerja    0
# Bukan Angkatan Kerja - Sekolah                                 0
# Bukan Angkatan Kerja - Mengurus Rumah Tangga                   0
# Bukan Angkatan Kerja - Lainnya                                 0
# Bukan Angkatan Kerja - Jumlah Bukan Angkatan Kerja             0
# Angkatan Kerja + Bukan Angkatan Kerja (Jumlah )                0
# Persentase Angkatan Kerja terhadap Penduduk Usia Kerja         0
# dtype: int64

# %% [markdown]
# ### 2020

# %%
status_pekerjaan2020_df.isnull().sum()
# Out:
# Provinsi                                                       0
# Angkatan Kerja - Bekerja                                       0
# Angkatan Kerja Pengangguran - Pernah Bekerja                   0
# Angkatan Kerja Pengangguran - Tidak Pernah Bekerja             0
# Angkatan Kerja Pengangguran - Jumlah                           0
# Angkatan Kerja - Jumlah Angkatan Kerja                         0
# Angkatan Kerja - Persentase Bekerja terhadap Angkatan Kerja    0
# Bukan Angkatan Kerja - Sekolah                                 0
# Bukan Angkatan Kerja - Mengurus Rumah Tangga                   0
# Bukan Angkatan Kerja - Lainnya                                 0
# Bukan Angkatan Kerja - Jumlah Bukan Angkatan Kerja             0
# Angkatan Kerja + Bukan Angkatan Kerja (Jumlah )                0
# Persentase Angkatan Kerja terhadap Penduduk Usia Kerja         0
# dtype: int64

# %% [markdown]
# ### 2019

# %%
status_pekerjaan2019_df.isnull().sum()
# Out:
# Provinsi                                                       0
# Angkatan Kerja - Bekerja                                       0
# Angkatan Kerja Pengangguran - Pernah Bekerja                   0
# Angkatan Kerja Pengangguran - Tidak Pernah Bekerja             0
# Angkatan Kerja Pengangguran - Jumlah                           0
# Angkatan Kerja - Jumlah Angkatan Kerja                         0
# Angkatan Kerja - Persentase Bekerja terhadap Angkatan Kerja    0
# Bukan Angkatan Kerja - Sekolah                                 0
# Bukan Angkatan Kerja - Mengurus Rumah Tangga                   0
# Bukan Angkatan Kerja - Lainnya                                 0
# Bukan Angkatan Kerja - Jumlah Bukan Angkatan Kerja             0
# Angkatan Kerja + Bukan Angkatan Kerja (Jumlah )                0
# Persentase Angkatan Kerja terhadap Penduduk Usia Kerja         0
# dtype: int64

# %% [markdown]
# ### 2018

# %%
status_pekerjaan2018_df.isnull().sum()
# Out:
# Provinsi                                                       0
# Angkatan Kerja - Bekerja                                       0
# Angkatan Kerja Pengangguran - Pernah Bekerja                   0
# Angkatan Kerja Pengangguran - Tidak Pernah Bekerja             0
# Angkatan Kerja Pengangguran - Jumlah                           0
# Angkatan Kerja - Jumlah Angkatan Kerja                         0
# Angkatan Kerja - Persentase Bekerja terhadap Angkatan Kerja    0
# Bukan Angkatan Kerja - Sekolah                                 0
# Bukan Angkatan Kerja - Mengurus Rumah Tangga                   0
# Bukan Angkatan Kerja - Lainnya                                 0
# Bukan Angkatan Kerja - Jumlah Bukan Angkatan Kerja             0
# Angkatan Kerja + Bukan Angkatan Kerja (Jumlah )                0
# Persentase Angkatan Kerja terhadap Penduduk Usia Kerja         0
# dtype: int64

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ### Mengechek Duplikasi Data

# %% [markdown]
# ### Jumlah Jenis Kelamin Tiap Tahun

# %% [markdown]
# ### Data Perkotaan

# %%
jumlah_duplikasi_perkotaan = data_perkotaan_df.duplicated().sum()
print(f"Jumlah duplikasi data perkotaan : {jumlah_duplikasi_perkotaan}")
# Out:
# Jumlah duplikasi data perkotaan : 0

# %% [markdown]
# ### Data Pedesaan

# %%
jumlah_duplikasi_pedesaan = data_pedesaan_df.duplicated().sum()
print(f"Jumlah duplikasi data pedesaan : {jumlah_duplikasi_pedesaan}")
# Out:
# Jumlah duplikasi data pedesaan : 0

# %% [markdown]
# ### Data Pencari, Terdaftar, dan Pemenuhan Tenaga Kerja

# %% [markdown]
# ### 2021

# %%
jumlah_duplikasi_pekerjaan2021 = data_pekerjaan2021_df.duplicated().sum()
print(f"Jumlah duplikasi data lowongan 2020 : {jumlah_duplikasi_pekerjaan2021}")
# Out:
# Jumlah duplikasi data lowongan 2020 : 0

# %% [markdown]
# ### 2020

# %%
jumlah_duplikasi_pekerjaan2020 = data_pekerjaan2020_df.duplicated().sum()
print(f"Jumlah duplikasi data lowongan 2020 : {jumlah_duplikasi_pekerjaan2020}")
# Out:
# Jumlah duplikasi data lowongan 2020 : 0

# %% [markdown]
# ### 2019

# %%
jumlah_duplikasi_pekerjaan2019 = data_pekerjaan2019_df.duplicated().sum()
print(f"Jumlah duplikasi data lowongan 2019 : {jumlah_duplikasi_pekerjaan2019}")
# Out:
# Jumlah duplikasi data lowongan 2019 : 0

# %% [markdown]
# ### 2018

# %%
jumlah_duplikasi_pekerjaan2018 = data_pekerjaan2018_df.duplicated().sum()
print(f"Jumlah duplikasi data lowongan 2018 : {jumlah_duplikasi_pekerjaan2018}")
# Out:
# Jumlah duplikasi data lowongan 2018 : 0

# %% [markdown]
# ### Data Jumlah Penduduk Provinsi dan Status Pekerjaannya

# %% [markdown]
# ### 2021

# %%
jumlah_duplikasi_status_pekerjaan2021 = status_pekerjaan2021_df.duplicated().sum()
print(f"Jumlah duplikasi status data pekerjaan 2021 : {jumlah_duplikasi_status_pekerjaan2021}")
# Out:
# Jumlah duplikasi status data pekerjaan 2021 : 0

# %% [markdown]
# ### 2020

# %%
jumlah_duplikasi_status_pekerjaan2020 = status_pekerjaan2020_df.duplicated().sum()
print(f"Jumlah duplikasi status data pekerjaan 2021 : {jumlah_duplikasi_status_pekerjaan2020}")
# Out:
# Jumlah duplikasi status data pekerjaan 2021 : 0

# %% [markdown]
# ### 2019

# %%
jumlah_duplikasi_status_pekerjaan2019 = status_pekerjaan2019_df.duplicated().sum()
print(f"Jumlah duplikasi status data pekerjaan 2021 : {jumlah_duplikasi_status_pekerjaan2019}")
# Out:
# Jumlah duplikasi status data pekerjaan 2021 : 0

# %% [markdown]
# ### 2018

# %%
jumlah_duplikasi_status_pekerjaan2018 = status_pekerjaan2018_df.duplicated().sum()
print(f"Jumlah duplikasi status data pekerjaan 2021 : {jumlah_duplikasi_status_pekerjaan2018}")
# Out:
# Jumlah duplikasi status data pekerjaan 2021 : 0

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ### Exploratory Data Analisis (EDA)

# %% [markdown]
# ### Mengeksplor rata-rata persentase jenis kelamin pada tahun 2021, 2020, 2019, dan 2018

# %% [markdown]
# ### Rata-rata laki-laki

# %%
average_perkotaan_laki2018 = data_perkotaan_df['2018_laki-laki'].mean()
average_perkotaan_laki2019 = data_perkotaan_df['2019_laki-laki'].mean()
average_perkotaan_laki2020 = data_perkotaan_df['2020_laki-laki'].mean()
average_perkotaan_laki2021 = data_perkotaan_df['2021_laki-laki'].mean()

total_average_laki_perkotaan = (average_perkotaan_laki2018 + average_perkotaan_laki2019 + average_perkotaan_laki2020 + average_perkotaan_laki2021) / 4
print(total_average_laki_perkotaan)
# Out:
# 84.94544871794872

# %% [markdown]
# ### Rata-rata perempuan

# %%
average_perkotaan_perempuan2018 = data_perkotaan_df['2018_perempuan'].mean()
average_perkotaan_perempuan2019 = data_perkotaan_df['2019_perempuan'].mean()
average_perkotaan_perempuan2020 = data_perkotaan_df['2020_perempuan'].mean()
average_perkotaan_perempuan2021 = data_perkotaan_df['2021_perempuan'].mean()

total_average_perempuan_perkotaan = (average_perkotaan_perempuan2018 + average_perkotaan_perempuan2019 + average_perkotaan_perempuan2020 + average_perkotaan_perempuan2021) / 4
print(total_average_perempuan_perkotaan)
# Out:
# 15.054551282051282

# %% [markdown]
# #

# %% [markdown]
# ### Mengeksplor persentase pertumbuhan penduduk berdasarkan jenis kelamin dari tahun 2018 sampai 2021

# %% [markdown]
# ### Laki-Laki

# %%
data_perkotaan_df['2018_laki-laki'] = data_perkotaan_df['2018_laki-laki'].replace(0, 1)
data_perkotaan_df['Pertumbuhan_Laki-laki_2018-2019'] = ((data_perkotaan_df['2019_laki-laki'] - data_perkotaan_df['2018_laki-laki']) / data_perkotaan_df['2018_laki-laki']) * 100
data_perkotaan_df['Pertumbuhan_Laki-laki_2019-2020'] = ((data_perkotaan_df['2020_laki-laki'] - data_perkotaan_df['2019_laki-laki']) / data_perkotaan_df['2019_laki-laki']) * 100
data_perkotaan_df['Pertumbuhan_Laki-laki_2020-2021'] = ((data_perkotaan_df['2021_laki-laki'] - data_perkotaan_df['2020_laki-laki']) / data_perkotaan_df['2020_laki-laki']) * 100

data_perkotaan_df[['Provinsi', '2018_laki-laki', '2019_laki-laki', 'Pertumbuhan_Laki-laki_2018-2019', '2020_laki-laki', 'Pertumbuhan_Laki-laki_2019-2020', '2021_laki-laki', 'Pertumbuhan_Laki-laki_2020-2021']]
# Out:
#                      Provinsi  2018_laki-laki  2019_laki-laki  \
# 0                        Aceh           80.35           82.36
# 1              Sumatera Utara           82.54           83.19
# 2              Sumatera Barat           83.46           81.79
# 3                     R i a u           87.76           87.99
# 4                   J a m b i           86.83           87.59
# 5            Sumatera Selatan           84.99           86.40
# 6                    Bengkulu           87.21           86.09
# 7                     Lampung           86.50           88.47
# 8   Kepulauan Bangka Belitung           88.36           89.38
# 9              Kepulauan Riau           88.74           88.81
# 10                DKI Jakarta           83.08           82.56
# 11                 Jawa Barat           86.29           86.44
# 12                Jawa Tengah           82.04           83.29
# 13              DI Yogyakarta           78.93           77.82
# ...

# %% [markdown]
# ### Perempuan

# %%
data_perkotaan_df['2018_perempuan'] = data_perkotaan_df['2018_perempuan'].replace(0, 1)
data_perkotaan_df['Pertumbuhan_Perempuan_2018-2019'] = ((data_perkotaan_df['2019_perempuan'] - data_perkotaan_df['2018_perempuan']) / data_perkotaan_df['2018_perempuan']) * 100
data_perkotaan_df['Pertumbuhan_Perempuan_2019-2020'] = ((data_perkotaan_df['2020_perempuan'] - data_perkotaan_df['2019_perempuan']) / data_perkotaan_df['2019_perempuan']) * 100
data_perkotaan_df['Pertumbuhan_Perempuan_2020-2021'] = ((data_perkotaan_df['2021_perempuan'] - data_perkotaan_df['2020_perempuan']) / data_perkotaan_df['2020_perempuan']) * 100

data_perkotaan_df[['Provinsi', '2018_perempuan', '2019_perempuan', 'Pertumbuhan_Perempuan_2018-2019', '2020_perempuan', 'Pertumbuhan_Perempuan_2019-2020', '2021_perempuan', 'Pertumbuhan_Perempuan_2020-2021']]
# Out:
#                      Provinsi  2018_perempuan  2019_perempuan  \
# 0                        Aceh           19.65           17.64
# 1              Sumatera Utara           17.46           16.81
# 2              Sumatera Barat           16.54           18.21
# 3                     R i a u           12.24           12.01
# 4                   J a m b i           13.17           12.41
# 5            Sumatera Selatan           15.01           13.60
# 6                    Bengkulu           12.79           13.91
# 7                     Lampung           13.50           11.53
# 8   Kepulauan Bangka Belitung           11.64           10.62
# 9              Kepulauan Riau           11.26           11.19
# 10                DKI Jakarta           16.92           17.44
# 11                 Jawa Barat           13.71           13.56
# 12                Jawa Tengah           17.96           16.71
# 13              DI Yogyakarta           21.07           22.18
# ...

# %% [markdown]
# ### Mengeksplor Persentase Pertumbuhan Angkatan Pernah Kerja Dari Tahun 2018 Sampai 2021

# %%
data_status = {
    'Provinsi' : status_pekerjaan2018_df['Provinsi'],
    'Status_2018' : status_pekerjaan2018_df['Angkatan Kerja Pengangguran - Pernah Bekerja'],
    'Status_2019' : status_pekerjaan2019_df['Angkatan Kerja Pengangguran - Pernah Bekerja'],
    'Pertumbuhan_2018-2019' : ((status_pekerjaan2019_df['Angkatan Kerja Pengangguran - Pernah Bekerja'] - status_pekerjaan2018_df['Angkatan Kerja Pengangguran - Pernah Bekerja']) / status_pekerjaan2018_df['Angkatan Kerja Pengangguran - Pernah Bekerja']) * 100,
    'Status_2020' : status_pekerjaan2020_df['Angkatan Kerja Pengangguran - Pernah Bekerja'],
    'Pertumbuhan_2019-2020' : ((status_pekerjaan2020_df['Angkatan Kerja Pengangguran - Pernah Bekerja'] - status_pekerjaan2019_df['Angkatan Kerja Pengangguran - Pernah Bekerja']) / status_pekerjaan2019_df['Angkatan Kerja Pengangguran - Pernah Bekerja']) * 100,
    'Status_2021' : status_pekerjaan2021_df['Angkatan Kerja Pengangguran - Pernah Bekerja'],
    'Pertumbuhan_2020-2021' : ((status_pekerjaan2021_df['Angkatan Kerja Pengangguran - Pernah Bekerja'] - status_pekerjaan2020_df['Angkatan Kerja Pengangguran - Pernah Bekerja']) / status_pekerjaan2020_df['Angkatan Kerja Pengangguran - Pernah Bekerja']) * 100
}

status_df = pd.DataFrame(data_status)
tabel_status = status_df[['Provinsi', 'Status_2018', 'Status_2019', 'Pertumbuhan_2018-2019', 'Status_2020', 'Pertumbuhan_2019-2020', 'Status_2021', 'Pertumbuhan_2020-2021']]
tabel_status
# Out:
#                      Provinsi  Status_2018  Status_2019  \
# 0                        Aceh        36176        38459
# 1              Sumatera Utara       153847       191274
# 2              Sumatera Barat        49311        60938
# 3                        Riau        76978        84774
# 4                       Jambi        25225        27903
# 5            Sumatera Selatan        71424        72720
# 6                    Bengkulu        15352        15444
# 7                     Lampung        86096        97938
# 8   Kepulauan Bangka Belitung        14649        13437
# 9              Kepulauan Riau        38290        46408
# 10                DKI Jakarta       138511       185198
# 11                 Jawa Barat       918640       976759
# 12                Jawa Tengah       472352       493576
# 13              DI Yogyakarta        43004        47371
# 14                 Jawa Timur       422282       422084
# 15                     Banten       221613       236409
# ...

# %% [markdown]
# ### Mengeksplor Pencari Kerja Pada Tahun 2018-2021

# %% [markdown]
# ### Laki-Laki

# %%
data_pencari_kerja_laki_df = {
    'Provinsi' : data_pekerjaan2018_df['Provinsi'],
    'Laki-Laki_Pencari_2018' : data_pekerjaan2018_df['Pencari Kerja Terdaftar - Laki-Laki'],
    'Laki-Laki_Pencari_2019' : data_pekerjaan2019_df['Pencari Kerja Terdaftar - Laki-Laki'],
    'Jumlah_Pencari_Kerja_Laki-Laki_2018-2019' : data_pekerjaan2019_df['Pencari Kerja Terdaftar - Laki-Laki'] - data_pekerjaan2018_df['Pencari Kerja Terdaftar - Laki-Laki'],
    'Laki-Laki_Pencari_2020' : data_pekerjaan2020_df['Pencari Kerja Terdaftar - Laki-Laki'],
    'Jumlah_Pencari_Kerja_Laki-Laki_2019-2020' : data_pekerjaan2020_df['Pencari Kerja Terdaftar - Laki-Laki'] - data_pekerjaan2019_df['Pencari Kerja Terdaftar - Laki-Laki'],
    'Laki-Laki_Pencari_2021' : data_pekerjaan2021_df['Pencari Kerja Terdaftar - Laki-Laki'],
    'Jumlah_Pencari_Kerja_Laki-Laki_2020-2021' : data_pekerjaan2021_df['Pencari Kerja Terdaftar - Laki-Laki'] - data_pekerjaan2020_df['Pencari Kerja Terdaftar - Laki-Laki'],
}
persentase_pencari_df = pd.DataFrame(data_pencari_kerja_laki_df)
persentase_pencari_df[['Provinsi', 'Laki-Laki_Pencari_2018', 'Laki-Laki_Pencari_2019', 'Jumlah_Pencari_Kerja_Laki-Laki_2018-2019', 'Laki-Laki_Pencari_2020', 'Jumlah_Pencari_Kerja_Laki-Laki_2019-2020', 'Laki-Laki_Pencari_2021', 'Jumlah_Pencari_Kerja_Laki-Laki_2020-2021']]
# Out:
#                      Provinsi  Laki-Laki_Pencari_2018  Laki-Laki_Pencari_2019  \
# 0                        Aceh                     855                     771
# 1              Sumatera Utara                    2324                    5585
# 2              Sumatera Barat                    4522                    4551
# 3                        Riau                    1879                    3963
# 4                       Jambi                    1865                    4079
# 5            Sumatera Selatan                    1587                    2729
# 6                    Bengkulu                     569                     956
# 7                     Lampung                    1578                    4789
# 8   Kepulauan Bangka Belitung                     492                     213
# 9              Kepulauan Riau                   11234                    3453
# 10                DKI Jakarta                    7674                    5251
# ...

# %% [markdown]
# ### Perempuan

# %%
data_pencari_kerja_Perempuan_df = {
    'Provinsi' : data_pekerjaan2018_df['Provinsi'],
    'Perempuan_Pencari_2018' : data_pekerjaan2018_df['Pencari Kerja Terdaftar - Perempuan'],
    'Perempuan_Pencari_2019' : data_pekerjaan2019_df['Pencari Kerja Terdaftar - Perempuan'],
    'Jumlah_Pencari_Kerja_Perempuan_2018-2019' : data_pekerjaan2019_df['Pencari Kerja Terdaftar - Perempuan'] - data_pekerjaan2018_df['Pencari Kerja Terdaftar - Perempuan'],
    'Perempuan_Pencari_2020' : data_pekerjaan2020_df['Pencari Kerja Terdaftar - Perempuan'],
    'Jumlah_Pencari_Kerja_Perempuan_2019-2020' : data_pekerjaan2020_df['Pencari Kerja Terdaftar - Perempuan'] - data_pekerjaan2019_df['Pencari Kerja Terdaftar - Perempuan'],
    'Perempuan_Pencari_2021' : data_pekerjaan2021_df['Pencari Kerja Terdaftar - Perempuan'],
    'Jumlah_Pencari_Kerja_Perempuan_2020-2021' : data_pekerjaan2021_df['Pencari Kerja Terdaftar - Perempuan'] - data_pekerjaan2020_df['Pencari Kerja Terdaftar - Perempuan'],
}
persentase_pencari_df = pd.DataFrame(data_pencari_kerja_Perempuan_df)
persentase_pencari_df[['Provinsi', 'Perempuan_Pencari_2018', 'Perempuan_Pencari_2019', 'Jumlah_Pencari_Kerja_Perempuan_2018-2019', 'Perempuan_Pencari_2020', 'Jumlah_Pencari_Kerja_Perempuan_2019-2020', 'Perempuan_Pencari_2021', 'Jumlah_Pencari_Kerja_Perempuan_2020-2021']]
# Out:
#                      Provinsi  Perempuan_Pencari_2018  Perempuan_Pencari_2019  \
# 0                        Aceh                     480                    1002
# 1              Sumatera Utara                    3644                    7721
# 2              Sumatera Barat                    6753                    5828
# 3                        Riau                    1740                    2607
# 4                       Jambi                    1458                    3102
# 5            Sumatera Selatan                    1601                    2778
# 6                    Bengkulu                     580                     770
# 7                     Lampung                    1525                    4011
# 8   Kepulauan Bangka Belitung                     553                     186
# 9              Kepulauan Riau                   10083                    3874
# 10                DKI Jakarta                    6281                    4401
# ...

# %% [markdown]
# ### Mengeksplor Lowongan Kerja Pada Tahun 2018-2021

# %% [markdown]
# ### Laki-Laki

# %%
data_lowongan_kerja_laki_df = {
    'Provinsi' : data_pekerjaan2018_df['Provinsi'],
    'Lowongan_Laki-Laki_2018' : data_pekerjaan2018_df['Lowongan Kerja Terdaftar - Laki-Laki'],
    'Lowongan_Laki-Laki_2019' : data_pekerjaan2019_df['Lowongan Kerja Terdaftar - Laki-Laki'],
    'Jumlah_Lowongan_Laki-Laki_2018-2019' : data_pekerjaan2019_df['Lowongan Kerja Terdaftar - Laki-Laki'] - data_pekerjaan2018_df['Lowongan Kerja Terdaftar - Laki-Laki'],
    'Lowongan_Laki-Laki_2020' : data_pekerjaan2020_df['Lowongan Kerja Terdaftar - Laki-Laki'],
    'Jumlah_Lowongan_Laki-Laki_2019-2020' : data_pekerjaan2020_df['Lowongan Kerja Terdaftar - Laki-Laki'] - data_pekerjaan2019_df['Lowongan Kerja Terdaftar - Laki-Laki'],
    'Lowongan_Laki-Laki_2021' : data_pekerjaan2021_df['Lowongan Kerja Terdaftar - Laki-Laki'],
    'Jumlah_Lowongan_Laki-Laki_2020-2021' : data_pekerjaan2021_df['Lowongan Kerja Terdaftar - Laki-Laki'] - data_pekerjaan2020_df['Lowongan Kerja Terdaftar - Laki-Laki'],
}
persentase_lowongan_laki_df = pd.DataFrame(data_lowongan_kerja_laki_df)
persentase_lowongan_laki_df[['Provinsi', 'Lowongan_Laki-Laki_2018', 'Lowongan_Laki-Laki_2019', 'Jumlah_Lowongan_Laki-Laki_2018-2019', 'Lowongan_Laki-Laki_2020', 'Jumlah_Lowongan_Laki-Laki_2019-2020', 'Lowongan_Laki-Laki_2021', 'Jumlah_Lowongan_Laki-Laki_2020-2021']]
# Out:
#                      Provinsi  Lowongan_Laki-Laki_2018  \
# 0                        Aceh                       36
# 1              Sumatera Utara                      399
# 2              Sumatera Barat                     1375
# 3                        Riau                      725
# 4                       Jambi                      743
# 5            Sumatera Selatan                     1416
# 6                    Bengkulu                      147
# 7                     Lampung                      251
# 8   Kepulauan Bangka Belitung                      166
# 9              Kepulauan Riau                     7365
# 10                DKI Jakarta                     5082
# 11                 Jawa Barat                     2344
# 12                Jawa Tengah                    31858
# 13              DI Yogyakarta                     7819
# 14                 Jawa Timur                     9304
# 15                     Banten                      768
# ...

# %% [markdown]
# ### Perempuan

# %%
data_lowongan_kerja_perempuan_df = {
    'Provinsi' : data_pekerjaan2018_df['Provinsi'],
    'Lowongan_Perempuan_2018' : data_pekerjaan2018_df['Lowongan Kerja Terdaftar - Perempuan'],
    'Lowongan_Perempuan_2019' : data_pekerjaan2019_df['Lowongan Kerja Terdaftar - Perempuan'],
    'Jumlah_Lowongan_Perempuan_2018-2019' : data_pekerjaan2019_df['Lowongan Kerja Terdaftar - Perempuan'] - data_pekerjaan2018_df['Lowongan Kerja Terdaftar - Perempuan'],
    'Lowongan_Perempuan_2020' : data_pekerjaan2020_df['Lowongan Kerja Terdaftar - Perempuan'],
    'Jumlah_Lowongan_Perempuan_2019-2020' : data_pekerjaan2020_df['Lowongan Kerja Terdaftar - Perempuan'] - data_pekerjaan2019_df['Lowongan Kerja Terdaftar - Perempuan'],
    'Lowongan_Perempuan_2021' : data_pekerjaan2021_df['Lowongan Kerja Terdaftar - Perempuan'],
    'Jumlah_Lowongan_Perempuan_2020-2021' : data_pekerjaan2021_df['Lowongan Kerja Terdaftar - Perempuan'] - data_pekerjaan2020_df['Lowongan Kerja Terdaftar - Perempuan'],
}
persentase_lowongan_perempuan_df = pd.DataFrame(data_lowongan_kerja_perempuan_df)
persentase_lowongan_perempuan_df[['Provinsi', 'Lowongan_Perempuan_2018', 'Lowongan_Perempuan_2019', 'Jumlah_Lowongan_Perempuan_2018-2019', 'Lowongan_Perempuan_2020', 'Jumlah_Lowongan_Perempuan_2019-2020', 'Lowongan_Perempuan_2021', 'Jumlah_Lowongan_Perempuan_2020-2021']]
# Out:
#                      Provinsi  Lowongan_Perempuan_2018  \
# 0                        Aceh                       36
# 1              Sumatera Utara                      858
# 2              Sumatera Barat                     1262
# 3                        Riau                      335
# 4                       Jambi                      567
# 5            Sumatera Selatan                     2124
# 6                    Bengkulu                      158
# 7                     Lampung                      292
# 8   Kepulauan Bangka Belitung                      117
# 9              Kepulauan Riau                     8053
# 10                DKI Jakarta                     2910
# 11                 Jawa Barat                     4248
# 12                Jawa Tengah                    55571
# 13              DI Yogyakarta                     8545
# 14                 Jawa Timur                    10834
# 15                     Banten                      961
# ...

# %% [markdown]
# ### Mengeksplor Penempatan /  Pemenuhan Tenaga Kerja Dari Tahun 2018-2021

# %% [markdown]
# ### Laki-Laki

# %%
data_penempatan_laki_df = {

    'Provinsi' : data_pekerjaan2018_df['Provinsi'],
    'Laki-Laki_Penerimaan_2018' : data_pekerjaan2018_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'],
    'Laki-Laki_Penerimaan_2019' : data_pekerjaan2019_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'],
    'Jumlah_Pertumbuhan_Laki-Laki_2018-2019' : data_pekerjaan2019_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'] - data_pekerjaan2018_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'],
    'Laki-Laki_Penerimaan_2020' : data_pekerjaan2020_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'],
    'Jumlah_Pertumbuhan_Laki-Laki_2019-2020' : data_pekerjaan2020_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'] - data_pekerjaan2019_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'],
    'Laki-Laki_Penerimaan_2021' : data_pekerjaan2021_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'],
    'Jumlah_Pertumbuhan_Laki-Laki_2020-2021' : data_pekerjaan2021_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'] - data_pekerjaan2020_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'],

}

persentase_lowongan_df = pd.DataFrame(data_penempatan_laki_df)
persentase_lowongan_df[['Provinsi', 'Laki-Laki_Penerimaan_2018', 'Laki-Laki_Penerimaan_2019', 'Jumlah_Pertumbuhan_Laki-Laki_2018-2019', 'Laki-Laki_Penerimaan_2020', 'Jumlah_Pertumbuhan_Laki-Laki_2019-2020', 'Laki-Laki_Penerimaan_2021', 'Jumlah_Pertumbuhan_Laki-Laki_2020-2021']]
# Out:
#                      Provinsi  Laki-Laki_Penerimaan_2018  \
# 0                        Aceh                         36
# 1              Sumatera Utara                         42
# 2              Sumatera Barat                       1375
# 3                        Riau                         94
# 4                       Jambi                        743
# 5            Sumatera Selatan                        399
# 6                    Bengkulu                        147
# 7                     Lampung                        304
# 8   Kepulauan Bangka Belitung                         36
# 9              Kepulauan Riau                       6390
# 10                DKI Jakarta                       2729
# 11                 Jawa Barat                         69
# 12                Jawa Tengah                      20321
# 13              DI Yogyakarta                       1757
# 14                 Jawa Timur                       4995
# ...

# %% [markdown]
# ### Perempuan

# %%
data_penempatan_perempuan_df = {
    'Provinsi' : data_pekerjaan2018_df['Provinsi'],
    'Penerimaan_Perempuan_2018' : data_pekerjaan2018_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'],
    'Penerimaan_Perempuan_2019' : data_pekerjaan2019_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'],
    'Jumlah_Pertumbuhan_Perempuan_2018-2019' : data_pekerjaan2019_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'] - data_pekerjaan2018_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'],
    'Penerimaan_Perempuan_2020' : data_pekerjaan2020_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'],
    'Jumlah_Pertumbuhan_Perempuan_2019-2020' : data_pekerjaan2020_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'] - data_pekerjaan2019_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'],
    'Penerimaan_Perempuan_2021' : data_pekerjaan2021_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'],
    'Jumlah_Pertumbuhan_Perempuan_2020-2021' : data_pekerjaan2021_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'] - data_pekerjaan2020_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'],
}

persentase_lowongan_df = pd.DataFrame(data_penempatan_perempuan_df)
persentase_lowongan_df[['Provinsi', 'Penerimaan_Perempuan_2018', 'Penerimaan_Perempuan_2019', 'Jumlah_Pertumbuhan_Perempuan_2018-2019', 'Penerimaan_Perempuan_2020', 'Jumlah_Pertumbuhan_Perempuan_2019-2020', 'Penerimaan_Perempuan_2021', 'Jumlah_Pertumbuhan_Perempuan_2020-2021']]
# Out:
#                      Provinsi  Penerimaan_Perempuan_2018  \
# 0                        Aceh                         27
# 1              Sumatera Utara                        158
# 2              Sumatera Barat                       1262
# 3                        Riau                         80
# 4                       Jambi                        567
# 5            Sumatera Selatan                        727
# 6                    Bengkulu                        158
# 7                     Lampung                        238
# 8   Kepulauan Bangka Belitung                          7
# 9              Kepulauan Riau                       6258
# 10                DKI Jakarta                       2427
# 11                 Jawa Barat                        133
# 12                Jawa Tengah                      32428
# 13              DI Yogyakarta                       2094
# 14                 Jawa Timur                       6265
# ...

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ### Data Visualisasi

# %% [markdown]
# ### Mengeksplore Rata-rata Pertumbuhan Penduduk Laki-laki dari Tahun 2018 sampai 2021

# %% [markdown]
# ### Perkotaan

# %%
# %matplotlib inline

tahun = ['2018', '2019', '2020', '2021']
perkotaan_average = {
    "Rata-rata_2018" : data_perkotaan_df["2018_laki-laki"].mean(),
    "Rata-rata_2019" : data_perkotaan_df["2019_laki-laki"].mean(),
    "Rata-rata_2020" : data_perkotaan_df["2020_laki-laki"].mean(),
    "Rata-rata_2021" : data_perkotaan_df["2021_laki-laki"].mean()
}

rata_rata_Laki_Perkotaan = [
    perkotaan_average["Rata-rata_2018"],
    perkotaan_average["Rata-rata_2019"],
    perkotaan_average["Rata-rata_2020"],
    perkotaan_average["Rata-rata_2021"]
]

plt.figure(figsize=(8,6))
bars = plt.bar(tahun, rata_rata_Laki_Perkotaan, color="silver")
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Posisi x (di tengah bar)
        height + 0.1,                      # Posisi y (sedikit di atas bar)
        f'{height:.2f}',                   # Format angka (2 desimal)
        ha='center',                       # Align horizontal
        va='bottom',                       # Align vertical
        fontsize=10,                       # Ukuran font
        color='black'                      # Warna teks
    )

plt.title('Rata-rata Laki-laki Perkotaan Tahun 2018-2021', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Rata-rata (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()


plt.show(block=True)
# Out:
# C:\Users\Khalif Umar Al Faruq\AppData\Local\Temp\ipykernel_31444\3178043225.py:36: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Insights
# ##### Pada visualisasi di atas, Didapat bahwa jumlah rata-rata penduduk Perkotaan berjenis kelamin laki-laki di setiap provinsi dari tahun 2018 sempat mengalami penurunan ke tahun 2019. Kemudian di tahun 2020 sampai 2021 mengalami kenaikan yang cukup signifikan.
# ##### Kesimpulannya : Jumlah penduduk berjenis kelamin laki-laki di Pedesaan mengalami penurunan pada saat pra-Covid-19 dan mengalami kenaikan pada saat pasca-Covid-19.

# %% [markdown]
# ### Pedesaan

# %%
tahun = ['2018', '2019', '2020', '2021']
pedesaan_average = {
    "Rata-rata_2018" : data_pedesaan_df["2018_laki-laki"].mean(),
    "Rata-rata_2019" : data_pedesaan_df["2019_laki-laki"].mean(),
    "Rata-rata_2020" : data_pedesaan_df["2020_laki-laki"].mean(),
    "Rata-rata_2021" : data_pedesaan_df["2021_laki-laki"].mean()
}

rata_rata_Laki_Pedesaan = [
    pedesaan_average["Rata-rata_2018"],
    pedesaan_average["Rata-rata_2019"],
    pedesaan_average["Rata-rata_2020"],
    pedesaan_average["Rata-rata_2021"]
]

plt.figure(figsize=(8,6))
bars = plt.bar(tahun, rata_rata_Laki_Pedesaan, color="silver")

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Posisi x (di tengah bar)
        height + 0.1,                      # Posisi y (sedikit di atas bar)
        f'{height:.2f}',                   # Format angka (2 desimal)
        ha='center',                       # Align horizontal
        va='bottom',                       # Align vertical
        fontsize=10,                       # Ukuran font
        color='black'                      # Warna teks
    )

plt.title('Rata-rata Laki-laki Pedesaan Tahun 2018-2021', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Rata-rata (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()


plt.show(block=True)
# Out:
# C:\Users\Khalif Umar Al Faruq\AppData\Local\Temp\ipykernel_31444\3979929904.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Insights
# ##### Pada visualisasi di atas, Didapat bahwa jumlah rata-rata penduduk Pedesaan berjenis kelamin laki-laki di setiap provinsi dari tahun 2018 sempat mengalami penurunan yang cukup drastis ke tahun 2019. Kemudian di tahun 2020 sampai 2021 mengalami kenaikan yang cukup signifikan.
# ##### Kesimpulannya : Jumlah penduduk berjenis kelamin laki-laki di Pedesaan mengalami penurunan pada saat pra-Covid-19 dan mengalami kenaikan pada saat pasca-Covid-19.

# %% [markdown]
# #

# %% [markdown]
# ### Mengeksplore Rata-rata Pertumbuhan Penduduk Perempuan dari Tahun 2018 sampai 2021

# %% [markdown]
# ### Perkotaan

# %%
tahun = ['2018', '2019', '2020', '2021']
perempuan_perkotaan_average = {
    "Rata-rata_2018" : data_perkotaan_df["2018_perempuan"].mean(),
    "Rata-rata_2019" : data_perkotaan_df["2019_perempuan"].mean(),
    "Rata-rata_2020" : data_perkotaan_df["2020_perempuan"].mean(),
    "Rata-rata_2021" : data_perkotaan_df["2021_perempuan"].mean()
}

rata_rata_perempuan_perkotaan = [
    perempuan_perkotaan_average["Rata-rata_2018"],
    perempuan_perkotaan_average["Rata-rata_2019"],
    perempuan_perkotaan_average["Rata-rata_2020"],
    perempuan_perkotaan_average["Rata-rata_2021"]
]

plt.figure(figsize=(8, 6))
bars = plt.bar(tahun, rata_rata_perempuan_perkotaan, color="gold")

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Posisi x (di tengah bar)
        height + 0.1,                      # Posisi y (sedikit di atas bar)
        f'{height:.2f}',                   # Format angka (2 desimal)
        ha='center',                       # Align horizontal
        va='bottom',                       # Align vertical
        fontsize=10,                       # Ukuran font
        color='black'                      # Warna teks
    )

plt.title('Rata-rata Perempuan Perkotaan Tahun 2018-2021', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Rata-rata (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

plt.show(block=True)

# %% [markdown]
# ### Insight
# ##### Pada visualisasi diatas, Didapat bahwa jumlah rata-rata penduduk Perkotaan berjenis kelamin perempuan di setiap provinsi dari tahun 2018 sempat mengalami kenaikan di tahun 2019. Kemudian di tahun 2020 sampai 2021 , mengalami penurunan yang cukup signifikan.
# ##### Kesimpulannya : Jumlah penduduk berjenis kelamin perempuan di Perkotaan mengalami kenaikan pada saat pra-Covid-19 dan mengalami penurunan pada saat pasca-Covid-19.

# %% [markdown]
# ### Pedesaan

# %%
tahun = ['2018', '2019', '2020', '2021']
perempuan_pedesaan_average = {
    "Rata-rata_2018" : data_pedesaan_df["2018_perempuan"].mean(),
    "Rata-rata_2019" : data_pedesaan_df["2019_perempuan"].mean(),
    "Rata-rata_2020" : data_pedesaan_df["2020_perempuan"].mean(),
    "Rata-rata_2021" : data_pedesaan_df["2021_perempuan"].mean()
}

rata_rata_perempuan_pedesaan = [
    perempuan_pedesaan_average["Rata-rata_2018"],
    perempuan_pedesaan_average["Rata-rata_2019"],
    perempuan_pedesaan_average["Rata-rata_2020"],
    perempuan_pedesaan_average["Rata-rata_2021"]
]

plt.figure(figsize=(8,6))
bars = plt.bar(tahun, rata_rata_perempuan_pedesaan, color='gold')

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Posisi x (di tengah bar)
        height + 0.1,                      # Posisi y (sedikit di atas bar)
        f'{height:.2f}',                   # Format angka (2 desimal)
        ha='center',                       # Align horizontal
        va='bottom',                       # Align vertical
        fontsize=10,                       # Ukuran font
        color='black'                      # Warna teks
    )

plt.title('Rata-rata Perempuan Pedesaan Tahun 2018-2021', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Rata-rata (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show(block=True)
# Out:
# C:\Users\Khalif Umar Al Faruq\AppData\Local\Temp\ipykernel_31444\1668018794.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Insight
# ##### Pada visualisasi diatas, Didapat bahwa jumlah rata-rata penduduk Pedesaan berjenis kelamin perempuan di setiap provinsi dari tahun 2018 sempat mengalami kenaikan di tahun 2019. Kemudian di tahun 2020 sampai 2021 , mengalami penurunan yang cukup signifikan.
# ##### Kesimpulannya : Jumlah penduduk berjenis kelamin perempuan di Pedesaan mengalami kenaikan pada saat pra-Covid-19 dan mengalami penurunan pada saat pasca-Covid-19.

# %% [markdown]
# #

# %% [markdown]
# ### Mengeksplor Pertumbuhan Pencari Kerja Dari 2018 - 2019

# %% [markdown]
# ### Laki-Laki

# %%
tahun = ['2018', '2019', '2020', '2021']
pencari_average_laki = {
    "Pencari_2018" : data_pekerjaan2018_df['Pencari Kerja Terdaftar - Laki-Laki'].mean(),
    "Pencari_2019" : data_pekerjaan2019_df['Pencari Kerja Terdaftar - Laki-Laki'].mean(),
    "Pencari_2020" : data_pekerjaan2020_df['Pencari Kerja Terdaftar - Laki-Laki'].mean(),
    "Pencari_2021" : data_pekerjaan2021_df['Pencari Kerja Terdaftar - Laki-Laki'].mean()    
}

pencari_laki_perkotaan = [
    pencari_average_laki["Pencari_2018"],
    pencari_average_laki["Pencari_2019"],
    pencari_average_laki["Pencari_2020"],
    pencari_average_laki["Pencari_2021"]
]

plt.figure(figsize=(8,6))
plt.plot(tahun, pencari_laki_perkotaan, marker='d', linestyle='-', color="green")

for i, value in enumerate(pencari_laki_perkotaan):
    plt.text(
        tahun[i],               # Posisi x (tahun)
        value + 0.5,            # Posisi y (sedikit di atas nilai data)
        f'{value:.2f}',         # Format angka dengan 2 desimal
        ha='center',            # Align horizontal
        va='bottom',            # Align vertical
        fontsize=10,            # Ukuran font
        color='black'           # Warna teks
    )

plt.title('Pertumbuhan Pencari Tenaga Kerja Laki-Laki Tahun 2018-2021', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Jumlah (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show(block=True)

# %% [markdown]
# ### Insight
# ##### Pada visualisasi di atas, Dapat dilihat bahwa jumlah rata-rata pertumbuhan laki-laki pencari kerja dari tahun 2018 sampai dengan 2020 mengalami kenaikan. Kemudian dari tahun 2020 ke tahun 2021 mengalami penurunan drastis.
# ##### Kesimpulannya : Jumlah rata-rata penduduk setiap provinsi berjenis kelamin laki-laki mengalami kenaikan drastis pada saat covid-19 mulai muncul di Indonesia. Dapat dilihat pada tahun 2019 ke 2020. Namun terdapat penurunan yang drastis juga pada tahun setelahnya.

# %% [markdown]
# ### Perempuan

# %%
tahun = ['2018', '2019', '2020', '2021']
pencari_average_perempuan = {
    "Pencari_2018" : data_pekerjaan2018_df['Pencari Kerja Terdaftar - Perempuan'].mean(),
    "Pencari_2019" : data_pekerjaan2019_df['Pencari Kerja Terdaftar - Perempuan'].mean(),
    "Pencari_2020" : data_pekerjaan2020_df['Pencari Kerja Terdaftar - Perempuan'].mean(),
    "Pencari_2021" : data_pekerjaan2021_df['Pencari Kerja Terdaftar - Perempuan'].mean()    
}

pencari_perempuan_perkotaan = [
    pencari_average_perempuan["Pencari_2018"],
    pencari_average_perempuan["Pencari_2019"],
    pencari_average_perempuan["Pencari_2020"],
    pencari_average_perempuan["Pencari_2021"]
]

plt.figure(figsize=(8,6))
plt.plot(tahun, pencari_perempuan_perkotaan, marker='d', linestyle='-', color="green")

for i, value in enumerate(pencari_perempuan_perkotaan):
    plt.text(
        tahun[i],               # Posisi x (tahun)
        value + 0.5,            # Posisi y (sedikit di atas nilai data)
        f'{value:.2f}',         # Format angka dengan 2 desimal
        ha='center',            # Align horizontal
        va='bottom',            # Align vertical
        fontsize=10,            # Ukuran font
        color='black'           # Warna teks
    )

plt.title('Pertumbuhan Pencari Tenaga Kerja Perempuan Tahun 2018-2021', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Jumlah (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show(block=True)
# Out:
# C:\Users\Khalif Umar Al Faruq\AppData\Local\Temp\ipykernel_31444\3514136889.py:34: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Insight
# ##### Pada visualisasi di atas, Dapat dilihat bahwa jumlah rata-rata pertumbuhan perempuan pencari kerja dari tahun 2018 sampai dengan 2020 mengalami kenaikan. Kemudian dari tahun 2020 ke tahun 2021 mengalami penurunan drastis. Kurang lebih sama seperti pertumbuhan laki-laki.
# ##### Kesimpulannya : Jumlah rata-rata penduduk setiap provinsi berjenis kelamin perempuan mengalami kenaikan drastis pada saat covid-19 mulai muncul di Indonesia. Dapat dilihat pada tahun 2019 ke 2020. Namun terdapat penurunan yang drastis juga pada tahun setelahnya.

# %% [markdown]
# #

# %% [markdown]
# ### Mengekplor Pertumbuhan Lowongan Kerja Dari 2018 - 2021

# %% [markdown]
# ### Laki-Laki

# %%
tahun = ['2018', '2019', '2020', '2021']
lowongan_average_laki = {
    "Lowongan_2018" : data_pekerjaan2018_df['Lowongan Kerja Terdaftar - Laki-Laki'].mean(),
    "Lowongan_2019" : data_pekerjaan2019_df['Lowongan Kerja Terdaftar - Laki-Laki'].mean(),
    "Lowongan_2020" : data_pekerjaan2020_df['Lowongan Kerja Terdaftar - Laki-Laki'].mean(),
    "Lowongan_2021" : data_pekerjaan2021_df['Lowongan Kerja Terdaftar - Laki-Laki'].mean()    
}

lowongan_laki_perkotaan = [
    lowongan_average_laki["Lowongan_2018"],
    lowongan_average_laki["Lowongan_2019"],
    lowongan_average_laki["Lowongan_2020"],
    lowongan_average_laki["Lowongan_2021"]
]

plt.figure(figsize=(8,6))
plt.plot(tahun, lowongan_laki_perkotaan, marker='d', linestyle='-', color="red")

for i, value in enumerate(lowongan_laki_perkotaan):
    plt.text(
        tahun[i],               # Posisi x (tahun)
        value + 0.5,            # Posisi y (sedikit di atas nilai data)
        f'{value:.2f}',         # Format angka dengan 2 desimal
        ha='center',            # Align horizontal
        va='bottom',            # Align vertical
        fontsize=10,            # Ukuran font
        color='black'           # Warna teks
    )

plt.title('Pertumbuhan Lowongan Kerja Laki-Laki Tahun 2018-2021', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Jumlah (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show(block=True)
# Out:
# C:\Users\Khalif Umar Al Faruq\AppData\Local\Temp\ipykernel_31444\1563441620.py:34: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Insight
# ##### Pada visualisasi di atas, Dapat dilihat bahwa jumlah rata-rata lowongon kerja laki-laki dari tahun 2018 sampai dengan 2020 mengalami kenaikan. Namun di tahun 2021 mengalami penurunan  yang cukup signifikan.
# ##### Kesimpulannya : Rata-rata jumlah lowongan kerja laki-laki di tahun 2019 ke 2020 mengalami pembeludakan lowongan pekerjaan yang mungkin disebabkan oleh adanya pandemi Covid-19. Namun di tahun setelahnya mengalami penurunan yang cukup signifikan.

# %% [markdown]
# ### Perempuan

# %%
tahun = ['2018', '2019', '2020', '2021']
lowongan_average_perempuan = {
    "Lowongan_2018" : data_pekerjaan2018_df['Lowongan Kerja Terdaftar - Perempuan'].mean(),
    "Lowongan_2019" : data_pekerjaan2019_df['Lowongan Kerja Terdaftar - Perempuan'].mean(),
    "Lowongan_2020" : data_pekerjaan2020_df['Lowongan Kerja Terdaftar - Perempuan'].mean(),
    "Lowongan_2021" : data_pekerjaan2021_df['Lowongan Kerja Terdaftar - Perempuan'].mean()    
}

lowongan_perempuan_perkotaan = [
    lowongan_average_perempuan["Lowongan_2018"],
    lowongan_average_perempuan["Lowongan_2019"],
    lowongan_average_perempuan["Lowongan_2020"],
    lowongan_average_perempuan["Lowongan_2021"]
]

plt.figure(figsize=(8,6))
plt.plot(tahun, lowongan_perempuan_perkotaan, marker='d', linestyle='-', color="red")

for i, value in enumerate(lowongan_perempuan_perkotaan):
    plt.text(
        tahun[i],               # Posisi x (tahun)
        value + 0.5,            # Posisi y (sedikit di atas nilai data)
        f'{value:.2f}',         # Format angka dengan 2 desimal
        ha='center',            # Align horizontal
        va='bottom',            # Align vertical
        fontsize=10,            # Ukuran font
        color='black'           # Warna teks
    )

plt.title('Pertumbuhan Lowongan Kerja Laki-Laki Tahun 2018-2021', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Jumlah (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show(block=True)
# Out:
# C:\Users\Khalif Umar Al Faruq\AppData\Local\Temp\ipykernel_31444\1440958281.py:34: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Insight
# ##### Pada visualisasi di atas, Dapat dilihat bahwa jumlah rata-rata lowongon kerja perempuan dari tahun 2018 sampai dengan 2020 mengalami kenaikan. Namun di tahun 2021 mengalami penurunan  yang cukup signifikan.
# ##### Kesimpulannya : Rata-rata jumlah lowongan kerja perempuan di tahun 2019 ke 2020 mengalami pembeludakan lowongan pekerjaan yang mungkin disebabkan oleh adanya pandemi Covid-19. Namun di tahun setelahnya mengalami penurunan yang cukup signifikan.

# %% [markdown]
# #

# %% [markdown]
# ### Mengeksplor Pertumbuhan Penempatan / Pemenuhan Tenaga Kerja Dari 2018 - 2021

# %% [markdown]
# ### Laki-Laki

# %%
tahun = ['2018', '2019', '2020', '2021']
penempatan_average_laki = {
    "Penempatan_2018" : data_pekerjaan2018_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'].mean(),
    "Penempatan_2019" : data_pekerjaan2019_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'].mean(),
    "Penempatan_2020" : data_pekerjaan2020_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'].mean(),
    "Penempatan_2021" : data_pekerjaan2021_df['Penempatan/Pemenuhan Tenaga Kerja - Laki-Laki'].mean()    
}

penempatan_laki_perkotaan = [
    penempatan_average_laki["Penempatan_2018"],
    penempatan_average_laki["Penempatan_2019"],
    penempatan_average_laki["Penempatan_2020"],
    penempatan_average_laki["Penempatan_2021"]
]

plt.figure(figsize=(8,6))
plt.plot(tahun, penempatan_laki_perkotaan, marker='d', linestyle='-', color="blue")

for i, value in enumerate(penempatan_laki_perkotaan):
    plt.text(
        tahun[i],               # Posisi x (tahun)
        value + 0.5,            # Posisi y (sedikit di atas nilai data)
        f'{value:.2f}',         # Format angka dengan 2 desimal
        ha='center',            # Align horizontal
        va='bottom',            # Align vertical
        fontsize=10,            # Ukuran font
        color='black'           # Warna teks
    )

plt.title('Pertumbuhan Penempatan Tenaga Kerja Laki-Laki Tahun 2018-2021', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Jumlah (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show(block=True)
# Out:
# C:\Users\Khalif Umar Al Faruq\AppData\Local\Temp\ipykernel_31444\2041077920.py:34: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Insight
# ##### Pada visualisasi di atas, Dapat dilihat bahwa jumlah penerimaan atau penempatan tenaga kerja laki-laki di tahun 2018 sampai dengan 2020 cukup mengalami kenaikan. Kemudian di tahun selanjutnya mengalami penurunan penerimaan tau penempatan tenaga kerja.
# ##### Kesimpulannya : Rata-rata jumlah tenaga kerja Permepuan yang diterima dari tahun 2018 ke 2020 mengalami kenaikan khususnya di tahun 2019 ke 2020 mengalami lojakan penerimaan tenaga kerja yang cukup signifikan. Namun di tahun setelahnya, penerimaan atau penempatan tenaga kerja mengalami penurunan yang cukup signifikan.

# %% [markdown]
# ### Perempuan

# %%
tahun = ['2018', '2019', '2020', '2021']
penempatan_average_perempuan = {
    "Penempatan_2018" : data_pekerjaan2018_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'].mean(),
    "Penempatan_2019" : data_pekerjaan2019_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'].mean(),
    "Penempatan_2020" : data_pekerjaan2020_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'].mean(),
    "Penempatan_2021" : data_pekerjaan2021_df['Penempatan/Pemenuhan Tenaga Kerja - Perempuan'].mean()    
}

penempatan_perempuan_perkotaan = [
    penempatan_average_perempuan["Penempatan_2018"],
    penempatan_average_perempuan["Penempatan_2019"],
    penempatan_average_perempuan["Penempatan_2020"],
    penempatan_average_perempuan["Penempatan_2021"]
]

plt.figure(figsize=(8,6))
plt.plot(tahun, penempatan_perempuan_perkotaan, marker='o', linestyle='-', color="blue")

for i, value in enumerate(penempatan_perempuan_perkotaan):
    plt.text(
        tahun[i],               # Posisi x (tahun)
        value + 0.5,            # Posisi y (sedikit di atas nilai data)
        f'{value:.2f}',         # Format angka dengan 2 desimal
        ha='center',            # Align horizontal
        va='bottom',            # Align vertical
        fontsize=10,            # Ukuran font
        color='black'           # Warna teks
    )

plt.title('Pertumbuhan Penempatan Tenaga Kerja Perempuan Tahun 2018-2021', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Jumlah (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show(block=True)
# Out:
# C:\Users\Khalif Umar Al Faruq\AppData\Local\Temp\ipykernel_31444\2639137011.py:34: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Insight
# ##### Pada visualisasi di atas, Dapat dilihat bahwa jumlah penerimaan atau penempatan tenaga kerja Perempuan di tahun 2018 sampai dengan 2020 cukup mengalami kenaikan. Kemudian di tahun selanjutnya mengalami penurunan penerimaan tau penempatan tenaga kerja.
# ##### Kesimpulannya : Rata-rata jumlah tenaga kerja Perempuan yang diterima dari tahun 2018 ke 2020 mengalami kenaikan khususnya di tahun 2019 ke 2020 mengalami lojakan penerimaan tenaga kerja yang cukup signifikan. Namun di tahun setelahnya, penerimaan atau penempatan tenaga kerja mengalami penurunan yang cukup signifikan.

# %% [markdown]
# #

# %% [markdown]
# ### Mengeksplor Pertumbuhan Angkatan Pernah Bekerja Dari 2018 - 2021

# %%
tahun = ['2018', '2019', '2020', '2021']
status_average = {
    'Status_2018' : status_pekerjaan2018_df['Angkatan Kerja Pengangguran - Pernah Bekerja'].mean(),
    'Status_2019' : status_pekerjaan2019_df['Angkatan Kerja Pengangguran - Pernah Bekerja'].mean(),
    'Status_2020' : status_pekerjaan2020_df['Angkatan Kerja Pengangguran - Pernah Bekerja'].mean(),
    'Status_2021' : status_pekerjaan2021_df['Angkatan Kerja Pengangguran - Pernah Bekerja'].mean()
}

pertumbuhan_status_pernah_bekerja = [
    status_average['Status_2018'],
    status_average['Status_2019'],
    status_average['Status_2020'],
    status_average['Status_2021']
]

plt.figure(figsize=(8,6))
plt.plot(tahun, pertumbuhan_status_pernah_bekerja, marker='o', linestyle='-', color="green")

for i, value in enumerate(pertumbuhan_status_pernah_bekerja):
    plt.text(
        tahun[i],               # Posisi x (tahun)
        value + 0.5,            # Posisi y (sedikit di atas nilai data)
        f'{value:.2f}',         # Format angka dengan 2 desimal
        ha='center',            # Align horizontal
        va='bottom',            # Align vertical
        fontsize=10,            # Ukuran font
        color='black'           # Warna teks
    )

plt.title('Pertumbuhan Angkatan Pernah Bekerja Dari 2018-2021', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Jumlah (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show(block=True)
# Out:
# C:\Users\Khalif Umar Al Faruq\AppData\Local\Temp\ipykernel_31444\1052676216.py:34: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import pandas as pd

# Data contoh
data = {
    'Provinsi': ['Provinsi A', 'Provinsi B', 'Provinsi C'],
    'Pencari Kerja': [1000, 2000, 1500],
    'Lowongan': [800, 1200, 1000],
    'Penerimaan': [700, 1100, 950]
}
df = pd.DataFrame(data)

# Perhitungan indikator
df['Rasio Penyerapan'] = df['Penerimaan'] / df['Pencari Kerja']
df['Rasio Ketersediaan Lowongan'] = df['Lowongan'] / df['Pencari Kerja']
df['Efisiensi Penyerapan'] = df['Penerimaan'] / df['Lowongan']

# Normalisasi indikator
df['Rasio Penyerapan (Normalisasi)'] = (df['Rasio Penyerapan'] - df['Rasio Penyerapan'].min()) / (df['Rasio Penyerapan'].max() - df['Rasio Penyerapan'].min())
df['Rasio Ketersediaan Lowongan (Normalisasi)'] = (df['Rasio Ketersediaan Lowongan'] - df['Rasio Ketersediaan Lowongan'].min()) / (df['Rasio Ketersediaan Lowongan'].max() - df['Rasio Ketersediaan Lowongan'].min())
df['Efisiensi Penyerapan (Normalisasi)'] = (df['Efisiensi Penyerapan'] - df['Efisiensi Penyerapan'].min()) / (df['Efisiensi Penyerapan'].max() - df['Efisiensi Penyerapan'].min())

# Kombinasi indikator dengan bobot
w1, w2, w3 = 0.5, 0.3, 0.2
df['Indeks Kualitas Industri'] = (w1 * df['Rasio Penyerapan (Normalisasi)'] +
                                  w2 * df['Rasio Ketersediaan Lowongan (Normalisasi)'] +
                                  w3 * df['Efisiensi Penyerapan (Normalisasi)'])

# Hasil
print(df[['Provinsi', 'Indeks Kualitas Industri']])
# Out:
#      Provinsi  Indeks Kualitas Industri
# 0  Provinsi A                  0.800000
# 1  Provinsi B                  0.111111
# 2  Provinsi C                  0.577778

# %% [markdown]
# ### Insight
# ##### Pada visualisasi di atas, Didapat bahwa rata-rata jumlah penduduk yang pernah bekerja dari tahunn 2018 sampai dengan 2020 mengalami kenaikan. Namun pada tahun selanjutnya mengalami penurunan pada tahun selanjutnya.
# ##### Kesimpulannya : Rata-rata jumlah penduduk yang pernah bekerja mengalami kenaikan di tahun 2018 sampai dengan 2020, khususnya 2020 mengalami lonjakan angkatan yang pernah bekerja yang memungkinkan terjadi PHK atau yang lainnya. Namun di tahun selanjutnya mengalami penurunan

# %% [markdown]
# #

# %% [markdown]
# ### Kesimpulan Analisis
# ##### Pertanyaan : Bagaimana Perbedaan Kondisi Lowongan Pekerjaan Pra-Covid19 dengan Pasca-Covid19?
# ##### Jawaban : Berdasarkan hasil dari eksplorasi pertumbuhan Jumlah Pencari, Lowongan, dan Penempatan kerja dapat disimpulkan bahwa disaat kondisi pra-Covid-19 atau sebelum adanya pandemi Covid-19 tepatnya tahun 2018 sampai 2019, jumlah Pencari, Lowongan, dan Penempatan kerja terbilang mengalami kenaikan secara normal. Namun, ketika pandemi Covid-19 masuk, membuat jumlah Pencari, Lowongan, dan Penempatan kerja naik secara drastis baik itu jumlah Pencari, Lowongan, ataupun Penempatan tenaga kerja. Hal tersebut memiliki kemungkinan bahwa terdapat krisis ekonomi yang membuat banyak karyawan terjerat PHK di setiap perusahaan yang ada di Indonesia. Namun ketika melihat tahun selanjutnya, terjadi penurunan yang cukup signifikan karena perusahaan sedikit demi sedikit mampu beradaptasi dengan adanya pandemi Covid-19.
